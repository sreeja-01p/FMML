# %% [markdown]
# <a href="https://colab.research.google.com/github/sreeja-01p/FMML/blob/main/Bayesian_ML_Applying_Bayes_Classifiers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-14 12:37:07--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   138MB/s    in 0.5s
#
# 2025-03-14 12:37:09 (138 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22915  1710.09768v1  Understanding and developing a correlation mea...  stat
# 3472   1708.00069v1  Unsupervised learning techniques in computer v...  stat
# 11385  1511.09159v1  The Support Vector Machine (SVM) has been used...  stat
# 22647  1703.06528v1  The massive amount of available data potential...  stat
# 4305    1107.2347v1  We describe a novel binary classification tech...  stat
# ...             ...                                                ...   ...
# 13659  1502.02444v1  In this research paper novel real/complex valu...    cs
# 9110   1505.07909v4  Intelligence Quotient (IQ) Test is a set of st...    cs
# 11758  1611.05780v4  In high dimensional regression settings, spars...  stat
# 40229  1802.02774v1  This paper focuses on fully understanding the ...    cs
# 22164  1506.03768v1  Learning of low dimensional structure in multi...  stat
#
#                                                    title  year  \
# 22915  From Distance Correlation to Multiscale Genera...  2017
# 3472   Learning Robust Representations for Computer V...  2017
# 11385  Proximal gradient method for huberized support...  2015
# 22647  Universal Consistency and Robustness of Locali...  2017
# 4305                BSVM: A Banded Suport Vector Machine  2011
# ...                                                  ...   ...
# 13659    On the Dynamics of a Recurrent Hopfield Network  2015
# 9110   Solving Verbal Comprehension Questions in IQ T...  2015
# 11758  Gap Safe screening rules for sparsity enforcin...  2016
# 40229  Learning to score and summarize figure skating...  2018
# 22164  Probabilistic Curve Learning: Coulomb Repulsio...  2015
#
#                                                 keywords
# 22915  [understanding, developing, correlation, depen...
# 3472   [unsupervised, techniques, representations, di...
# 11385  [classification, differentiable, difficult, pa...
# 22647  [available, potentially, challenge, algorithms...
# 4305   [classification, technique, formulation, encou...
# ...                                                  ...
# 13659  [realcomplex, recurrent, synthesizing, landsca...
# 9110   [intelligence, standardized, questions, intell...
# 11758  [dimensional, regression, enforcing, penalties...
# 40229  [understanding, particular, annotated, differe...
# 22164  [dimensional, structure, multidimensional, can...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22915    [understanding, developing, correlation, depen...
# 3472     [unsupervised, techniques, representations, di...
# 11385    [classification, differentiable, difficult, pa...
# 22647    [available, potentially, challenge, algorithms...
# 4305     [classification, technique, formulation, encou...
#                                ...
# 12611    [variational, autoencoder, effective, producin...
# 15565    [investigate, different, approaches, identific...
# 20962    [intuitively, obedience, following, preference...
# 33829    [pathfinding, hospitals, challenging, employee...
# 30828    [visualize, different, incorporating, hallucin...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8748 words.
# Out of those 4609 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1b588e32-cde2-4842-9e58-882604e724c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1b588e32-cde2-4842-9e58-882604e724c1")) {                    Plotly.newPlot(                        "1b588e32-cde2-4842-9e58-882604e724c1",                        [{"x":["correlations","performance","nonlinear","statistic","illustrated","scientific","advantages","asymptotic","theoretically","statistics","variables","dependencies","population","convergence","desirable","multivariate","discoveries","discovery","understand","formalize","characteristic","incorporating","comprehensive","mechanism","significant","utilizing","properties","univariate","achieving","underlying","theoretical","correlation","simulations","developing","connection","algorithmic","multiscale","functions","machinery","generalized","improvement","understanding","empirically","imperative","dimensional","interpretation","approaches","subspaces","unsupervised","techniques","contributions","clustering","representation","foreground","development","obscuring","background","representations","synthetic","algorithm","accelerate","approximation","experiments","considers","assumptions","superiority","generalize","demonstrate","regularization","difficult","extensive","differentiable","classification","converges","particular","convexity","regularized","numerical","capacities","localized","consistency","challenge","different","parametric","furthermore","consistent","universal","additionally","algorithms","structures","potentially","available","statistical","robustness","objective","specified","boundaries","encouraged","technique","formulation","encourages","associated","computational","uncertainty","recognition","cheminformatics","distributions","distribution","essential","bottleneck","equivalent","expansion","assessment","estimating","polynomial","applications","notational","necessary","probability","bioinformatics","information","estimation","rademacher","parametrically","consideration","estimators","empirical","estimator","embedding","important","principal","component","shrinkage","evaluations","existence","phenomenon","reproducing","benchmark","efficient","outperform","disconnected","piecewise","sequential","multidimensional","hierarchical","multispectral","generalization","segmentation","approximations","extracted","promising","diagnosis","represented","classifiers","consisting","automatic","subsequently","initially","classifier","appreciable","respectively","initialization","recommendation","according","favourably","experimentally","stochastic","motivated","advantage","interface","regularizers","converted","adversarial","supervision","synthesized","generates","engineered","additional","categories","recognize","naturally","traditional","outperforms","specifically","demonstrated","generated","descriptions","capability","consistently","discrimination","generative","effective","benchmarks","discussion","application","correction","percentage","candidate","potential","technology"],"y":[27,856,66,2,18,31,103,21,35,56,131,46,39,99,36,23,2,58,62,14,23,66,74,90,229,38,217,7,76,117,157,68,41,71,32,34,13,223,1,61,157,154,67,3,161,63,414,22,147,375,48,168,364,22,130,1,89,247,144,793,27,115,652,34,67,42,50,590,87,148,190,24,513,23,262,12,34,74,2,19,59,147,733,26,173,92,37,69,599,150,44,286,154,97,169,40,46,2,232,88,14,119,296,83,385,1,109,194,73,11,54,23,41,66,73,429,1,92,151,9,681,201,4,0,32,16,144,28,107,392,32,108,6,45,32,26,7,224,432,87,3,11,70,14,98,7,103,225,37,133,106,59,72,123,60,195,28,12,157,1,73,28,28,110,4,39,128,68,79,27,6,13,98,60,17,55,11,122,69,44,61,182,243,185,97,160,39,57,44,21,120,260,102,39,249,25,6,41,164,60],"type":"bar"},{"x":["correlations","performance","nonlinear ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4609,), (4609, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8183333333333334

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Mean</span> <span style=''>Shift</span> <span style=''>Priors</span> <span style=''>for</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.7500000000000001);'>Restoration</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>image</span> <span style=''>prior</span> <span style=''>that</span> <span style=''>directly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>represents</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>smoothed</span> <span style=''>version</span> <span style=''>of</span> <span style=''>the</span> <span style=''>natural</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3344768439108062);'>distribution</span> <span style=''>We</span> <span style=''>include</span> <span style=''>our</span> <span style=''>prior</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.7500000000000001);'>restoration</span> <span style=''>as</span> <span style=''>a</span> <span style=''>Bayes</span> <span style='background-color:rgba(255, 0, 0, 0.656441717791411);'>estimator</span> <span style=''>that</span> <span style=''>also</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>noise</span> <span style=''>blind</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.7500000000000001);'>restoration</span> <span style=''>problems</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>of</span> <span style=''>our</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponds</span> <span style=''>to</span> <span style=''>the</span> <span style=''>mean</span> <span style=''>shift</span> <span style=''>vector</span> <span style=''>on</span> <span style=''>the</span> <span style=''>natural</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3344768439108062);'>distribution</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>we</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>mean</span> <span style=''>shift</span> <span style=''>vector</span> <span style=''>field</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoders</span> <span style=''>and</span> <span style=''>use</span> <span style=''>it</span> <span style=''>in</span> <span style=''>a</span> <span style=''>gradient</span> <span style=''>descent</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>Bayes</span> <span style=''>risk</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>competitive</span> <span style=''>results</span> <span style=''>for</span> <span style=''>noise</span> <span style=''>blind</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>deblurring</span> <span style=''>super</span> <span style='background-color:rgba(0, 255, 0, 0.6438356164383561);'>resolution</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>demosaicing</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>Optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalizability</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Parametric</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>of</span> <span style=''>the</span> <span style=''>learner</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determined</span> <span style=''>by</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style=''>loss</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Employing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>with</span> <span style=''>possibly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>the</span> <span style=''>inferred</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>vector</span> <span style=''>will</span> <span style=''>be</span> <span style=''>biased</span> <span style=''>toward</span> <span style=''>the</span> <span style=''>training</span> <span style=''>samples</span> <span style=''>Such</span> <span style=''>bias</span> <span style=''>is</span> <span style=''>measured</span> <span style=''>by</span> <span style=''>the</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>where</span> <span style=''>the</span> <span style=''>data</span> <span style=''>set</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>partitioned</span> <span style=''>into</span> <span style=''>a</span> <span style=''>training</span> <span style=''>set</span> <span style=''>used</span> <span style=''>for</span> <span style=''>training</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>set</span> <span style=''>which</span> <span style=''>is</span> <span style=''>not</span> <span style=''>used</span> <span style=''>in</span> <span style=''>training</span> <span style=''>and</span> <span style=''>is</span> <span style=''>left</span> <span style=''>to</span> <span style=''>measure</span> <span style=''>the</span> <span style=''>out</span> <span style=''>of</span> <span style=''>sample</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classical</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>strategy</span> <span style=''>is</span> <span style=''>the</span> <span style=''>leave</span> <span style=''>one</span> <span style=''>out</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>(LOOCV)</span> <span style=''>where</span> <span style=''>one</span> <span style=''>sample</span> <span style=''>is</span> <span style=''>left</span> <span style=''>out</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>and</span> <span style=''>training</span> <span style=''>is</span> <span style=''>done</span> <span style=''>on</span> <span style=''>the</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Convex</span> <span style='background-color:rgba(255, 0, 0, 0.3682539682539683);'>Inference</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Marginals</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3670886075949368);'>Graphical</span> <span style=''>models</span> <span style=''>trained</span> <span style=''>using</span> <span style=''>maximum</span> <span style='background-color:rgba(255, 0, 0, 0.5080645161290324);'>likelihood</span> <span style=''>are</span> <span style=''>a</span> <span style=''>common</span> <span style=''>tool</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3682539682539683);'>inference</span> <span style=''>of</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3453453453453455);'>distributions</span> <span style=''>However</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>suffers</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficulties</span> <span style=''>when</span> <span style=''>either</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3682539682539683);'>inference</span> <span style=''>process</span> <span style=''>or</span> <span style=''>the</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3682539682539683);'>inference</span> <span style=''>process</span> <span style=''>is</span> <span style=''>first</span> <span style=''>defined</span> <span style=''>to</span> <span style=''>be</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>of</span> <span style=''>a</span> <span style=''>convex</span> <span style=''>function</span> <span style=''>inspired</span> <span style=''>by</span> <span style=''>free</span> <span style=''>energy</span> <span style='background-color:rgba(255, 0, 0, 0.3781512605042018);'>approximations</span> <span style=''>Learning</span> <span style=''>is</span> <span style=''>then</span> <span style=''>done</span> <span style=''>directly</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3682539682539683);'>inference</span> <span style=''>process</span> <span style=''>at</span> <span style='background-color:rgba(255, 0, 0, 0.4814814814814815);'>univariate</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>The</span> <span style=''>main</span> <span style=''>novelty</span> <span style=''>is</span> <span style=''>that</span> <span style=''>this</span> <span style=''>is</span> <span style=''>a</span> <span style=''>direct</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>minimization</span> <span style=''>of</span> <span style=''>emperical</span> <span style=''>risk</span> <span style=''>where</span> <span style=''>the</span> <span style=''>risk</span> <span style=''>measures</span> <span style=''>the</span> <span style=''>accuracy</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>predicted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>marginals</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Collaborative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>filtering</span> <span style=''>via</span> <span style=''>sparse</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>fields</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Recommender</span> <span style=''>systems</span> <span style=''>play</span> <span style=''>a</span> <span style=''>central</span> <span style=''>role</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>providing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>individualized</span> <span style=''>access</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>and</span> <span style=''>services</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>focuses</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collaborative</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>filtering</span> <span style=''>an</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>exploits</span> <span style=''>the</span> <span style=''>shared</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>among</span> <span style=''>mind</span> <span style=''>liked</span> <span style=''>users</span> <span style=''>and</span> <span style=''>similar</span> <span style=''>items</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>a</span> <span style=''>formal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>known</span> <span style=''>as</span> <span style=''>Markov</span> <span style=''>random</span> <span style=''>fields</span> <span style=''>(MRF)</span> <span style=''>We</span> <span style=''>address</span> <span style=''>the</span> <span style=''>open</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structure</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>sparsity</span> <span style=''>inducing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatically</span> <span style=''>estimate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interaction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>between</span> <span style=''>users</span> <span style=''>and</span> <span style=''>between</span> <span style=''>items</span> <span style=''>Item</span> <span style=''>item</span> <span style=''>and</span> <span style=''>user</span> <span style=''>user</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>correlation</span> <span style=''>networks</span> <span style=''>are</span> <span style=''>obtained</span> <span style=''>as</span> <span style=''>a</span> <span style=''>by</span> <span style=''>product</span> <span style=''>Large</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>on</span> <span style=''>movie</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>recommendation</span> <span style=''>and</span> <span style=''>date</span> <span style=''>matching</span> <span style=''>datasets</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style=''>power</span> <span style=''>of</span> <span style=''>the</span> <span style ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	representation (0.13023255813953488)
# 	knowledge (0.12915921288014312)
# 	processing (0.1076923076923077)
# 	experimental (0.13774597495527727)
# 	information (0.24364937388193203)
# 	segmentation (0.08050089445438283)
# 	different (0.2622540250447227)
# 	detection (0.12415026833631485)
# 	recognition (0.13774597495527727)
# 	convolutional (0.1409660107334526)
#
# Some Statistics words are:
# 	variables (0.13216957605985039)
# 	stochastic (0.1316708229426434)
# 	statistical (0.15112219451371572)
# 	algorithm (0.38104738154613466)
# 	theoretical (0.15511221945137157)
# 	estimation (0.17256857855361596)
# 	distribution (0.19401496259351622)
# 	regression (0.17356608478802993)
# 	dimensional (0.19600997506234413)
# 	inference (0.21496259351620947)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7836be7d-5fe2-455d-bea4-1ea8a8aabe49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7836be7d-5fe2-455d-bea4-1ea8a8aabe49")) {                    Plotly.newPlot(                        "7836be7d-5fe2-455d-bea4-1ea8a8aabe49",                        [{"x":["correlations","performance","nonlinear","statistic","illustrated","scientific","advantages","asymptotic","theoretically","statistics","variables","dependencies","population","convergence","desirable","multivariate","discoveries","discovery","understand","formalize","characteristic","incorporating","comprehensive","mechanism","significant","utilizing","properties","univariate","achieving","underlying","theoretical","correlation","simulations","developing","connection","algorithmic","multiscale","functions","machinery","generalized","improvement","understanding","empirically","imperative","dimensional","interpretation","approaches","subspaces","unsupervised","techniques","contributions","clustering","representation","foreground","development","obscuring","background","representations","synthetic","algorithm","accelerate","approximation","experiments","considers","assumptions","superiority","generalize","demonstrate","regularization","difficult","extensive","differentiable","classification","converges","particular","convexity","regularized","numerical","capacities","localized","consistency","challenge","different","parametric","furthermore","consistent","universal","additionally","algorithms","structures","potentially","available","statistical","robustness","objective","specified","boundaries","encouraged","technique","formulation","encourages","associated","computational","uncertainty","recognition","cheminformatics","distributions","distribution","essential","bottleneck","equivalent","expansion","assessment","estimating","polynomial","applications","notational","necessary","probability","bioinformatics","information","estimation","rademacher","parametrically","consideration","estimators","empirical","estimator","embedding","important","principal","component","shrinkage","evaluations","existence","phenomenon","reproducing","benchmark","efficient","outperform","disconnected","piecewise","sequential","multidimensional","hierarchical","multispectral","generalization","segmentation","approximations","extracted","promising","diagnosis","represented","classifiers","consisting","automatic","subsequently","initially","classifier","appreciable","respectively","initialization","recommendation","according","favourably","experimentally","stochastic","motivated","advantage","interface","regularizers","converted","adversarial","supervision","synthesized","generates","engineered","additional","categories","recognize","naturally","traditional","outperforms","specifically","demonstrated","generated","descriptions","capability","consistently","discrimination","generative","effective","benchmarks","discussion","application","correction","percentage","candidate","potential","technology","especially","management","companies","marketing","presidential","reweighting","analytics","sentiment","increasing","anonymous","conjunction","individual","extremely","excitatory","interactions","variational","specifying","structure","sequences","friendships","computationally","inference","structured","financial","observable","relationships","connectomics","proposing","connecting","constituents","observations","intuition","likelihood","corresponding","optimization","guarantees","extensions","extension","predictor","selecting","operators","components","variation","detection","knowledge","decreasing","submodular","predictors","symmetric","translations","rotations","harmonics","consequences","augmentation","g ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	parametrically
# 	presidential
# 	elegantly
# 	integrality
# 	idealized
# 	martingale
# 	converged
# 	blockwise
# 	emphsparse
# 	precludes
# 	looseness
# 	divisible
# 	specializes
# 	practitioner
# 	clarifies
# 	davenport
# 	dissimilarities
# 	colombian
# 	tabulation
# 	regressionclassification
# Some words which never appear in Statistics papers:
# 	harmonics
# 	orientations
# 	intrusions
# 	interfering
# 	strategically
# 	involvement
# 	predicates
# 	preparation
# 	requisite
# 	quantifiers
# 	decompression
# 	harnessed
# 	compositionality
# 	minimality
# 	authenticate
# 	authentication
# 	backpacks
# 	grammaires
# 	syntactical
# 	dépendances

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.071347400104426e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7683333333333333
